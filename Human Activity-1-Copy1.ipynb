# %% [markdown]
# # NB and Logistic Regression Project
#
# Welcome to NB and Logistic Regression Project! Go ahead and just follow the directions below.

# %%
#  build a classification model which will recognise the activities through the mobile sensor. 
# like walking ,walking_upstairs  ,walking_downstairs ,sitting  ,standing,lying.
# The topic Human Activity recognition is in research 
# and has its own advantages like anomaly detection, 
# for healthy diet maintenance fitness bands are used , 
# measuring stress level ,for monitoring employees ,for heartbeat pulse rate etc. 
# In this paper we are going to focus on  the dataset which was carried out through experiments  
# with a group of 30 volunteers wearing a smartphone.
# The experiments have been video-recorded to label the data manually.
# The  main motto is to use the dataset and work with the libraries like scikit learn and machine learning related libraries and algorithms while training .

# %% [markdown]
# ## Import Libraries
# **Import pandas,seaborn, and the usual libraries.**

# %% [markdown]
# # EDA - To Explain Data

# %% [markdown]
# # Null/Outlier Treatment

# %% [markdown]
# # Remove non-Important Features

# %%
X = dataset.drop(['subject','Activity'],axis=1)

# %%
y = dataset['Activity']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

dataset_model =  DecisionTreeClassifier(random_state=1)
dataset_model.fit(X_train, y_train)
pred = dataset_model.predict(X_test)
from sklearn.metrics import precision_score,recall_score
print('precision_score : ',precision_score(y_test,pred,average='weighted'))
print('recall_score: ',recall_score(y_test,pred,average='weighted'))
# Out:
# precision_score :  0.9504217307092754
# recall_score:  0.9503738953093134

# %% [markdown]
# # Plot confusion Matrix

# %%
# !pip install scikit-plot --quiet
# Out:
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\amit.kumar02\miniconda3\envs\poc\python.exe -m pip install --upgrade pip' command.

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt 
# Plot confusion Matrix
skplt.metrics.plot_confusion_matrix(y_test, pred, figsize=(10, 8))
plt.show()

# %%
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
model = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Accuracy",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy 0.7307953772943576

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt 
# Plot confusion Matrix
skplt.metrics.plot_confusion_matrix(y_test, y_pred, figsize=(10, 8))
plt.show()

# %%
from sklearn.linear_model import SGDClassifier
# from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB,GaussianNB,ComplementNB,BernoulliNB,CategoricalNB
from sklearn.linear_model import LogisticRegression

from sklearn import metrics

algorithm = {
    "GaussianNB":GaussianNB(),
#     "MultinomialNB":MultinomialNB(),
#     "ComplementNB":ComplementNB(),
    "BernoulliNB":BernoulliNB(),
#     "CategoricalNB":CategoricalNB(),
    "SGDClassifier":SGDClassifier(),
    "LogisticRegression": LogisticRegression()
}

model_object = {}

prediction ={}

for id,classifier in algorithm.items():
    clf = classifier
    print("Training for : "+id)
    model = clf.fit(X_train, y_train)
    model_object[id]=model
    y_pred = clf.predict(X_test)
    prediction[id]=y_pred
    # Model Accuracy, how often is the classifier correct?
    print("Accuracy for"+id+":",metrics.accuracy_score(y_test, y_pred))
# Out:
# Training for : GaussianNB
# Accuracy forGaussianNB: 0.7307953772943576
# Training for : BernoulliNB
# Accuracy forBernoulliNB: 0.8592794017675051
# Training for : SGDClassifier
# Accuracy forSGDClassifier: 0.9775662814411965
# Training for : LogisticRegression
# Accuracy forLogisticRegression: 0.9864038069340585
# c:\users\amit.kumar02\miniconda3\envs\poc\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt 
# Plot confusion Matrix
skplt.metrics.plot_confusion_matrix(y_test, prediction["LogisticRegression"], figsize=(10, 8))
plt.show()
